# %%
import h5py
from pathlib import Path
import os

file_list = os.listdir("/home/fk/python_code/data/Vaihingen")
print(file_list)
# Out:
# ['full_test_vaih.hdf5', 'full_training_vaih.hdf5']

# %%
with h5py.File("/home/fk/python_code/data/Vaihingen/full_training_vaih.hdf5", "r") as f:
    for name in f:
        print(name)
# Out:
# imgs
# mask_single

# %%
import h5py

def print_structure(name, obj):
    if isinstance(obj, h5py.Group):
        print(f'Group: {name}')
    elif isinstance(obj, h5py.Dataset):
        print(f'Dataset: {name} (shape: {obj.shape}, dtype: {obj.dtype})')
    # Recursively traverse groups
    if isinstance(obj, h5py.Group):
        for key, item in obj.items():
            print_structure(f'{name}/{key}', item)

# 打开 HDF5 文件
with h5py.File('/home/fk/python_code/data/Vaihingen/full_training_vaih.hdf5', 'r') as f:
    print('HDF5 File Structure:')
    # 从根组开始遍历
    for key, item in f.items():
        print_structure(key, item)
# Out:
# HDF5 File Structure:
# Group: imgs
# Dataset: imgs/building_001 (shape: (256, 256, 3), dtype: uint8)
# Dataset: imgs/building_002 (shape: (256, 256, 3), dtype: uint8)
# Dataset: imgs/building_003 (shape: (256, 256, 3), dtype: uint8)
# Dataset: imgs/building_004 (shape: (256, 256, 3), dtype: uint8)
# Dataset: imgs/building_005 (shape: (256, 256, 3), dtype: uint8)
# Dataset: imgs/building_006 (shape: (256, 256, 3), dtype: uint8)
# Dataset: imgs/building_007 (shape: (256, 256, 3), dtype: uint8)
# Dataset: imgs/building_008 (shape: (256, 256, 3), dtype: uint8)
# Dataset: imgs/building_009 (shape: (256, 256, 3), dtype: uint8)
# Dataset: imgs/building_010 (shape: (256, 256, 3), dtype: uint8)
# Dataset: imgs/building_011 (shape: (256, 256, 3), dtype: uint8)
# Dataset: imgs/building_012 (shape: (256, 256, 3), dtype: uint8)
# Dataset: imgs/building_013 (shape: (256, 256, 3), dtype: uint8)
# Dataset: imgs/building_014 (shape: (256, 256, 3), dtype: uint8)
# ...

# %%
import os

# 打印所有环境变量及其值
for key, value in os.environ.items():
    print(f'{key}: {value}')
# Out:
# SHELL: /bin/bash
# PWD: /home/fk
# LOGNAME: fk
# MOTD_SHOWN: pam
# HOME: /home/fk
# SSL_CERT_DIR: /usr/lib/ssl/certs
# VSCODE_AGENT_FOLDER: /home/fk/.vscode-server
# SSH_CONNECTION: 172.20.110.124 53187 172.17.0.6 2222
# USER: fk
# SHLVL: 2
# SSL_CERT_FILE: /usr/lib/ssl/certs/ca-certificates.crt
# SSH_CLIENT: 172.20.110.124 53187 2222
# VSCODE_CLI_REQUIRE_TOKEN: c7afede3-4114-4604-be20-f49c4bde6075
# _CUDA_COMPAT_PATH: /usr/local/cuda/compat
# PATH: /home/fk/miniconda3/envs/segdiff/bin:/home/fk/.vscode-server/cli/servers/Stable-b1c0a14de1414fcdaa400695b4db1c0799bc3124/server/bin/remote-cli:/home/fk/miniconda3/envs/segdiff/bin:/home/fk/miniconda3/condabin:/usr/local/nvm/versions/node/v16.20.2/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin
# OLDPWD: /home/fk/.vscode-server
# _: /home/fk/miniconda3/envs/segdiff/bin/python
# VSCODE_CWD: /home/fk
# ...

# %%
import os

os.environ['CUDA_VISIBLE_DEVICES'] = '0,1'
# 获取环境变量 CUDA_VISIBLE_DEVICES 的值
cuda_visible_devices = os.environ.get('CUDA_VISIBLE_DEVICES', None)
print(f"CUDA_VISIBLE_DEVICES: {cuda_visible_devices}")
# Out:
# CUDA_VISIBLE_DEVICES: 0,1
